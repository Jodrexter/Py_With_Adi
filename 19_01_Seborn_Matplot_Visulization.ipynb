# %%
import pandas as pd

# %%
df = pd.read_csv("D:/ETL HIVE/PYTHON/ADV PY/Cars93.csv")

# %%
df
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
# show the top 3 rows of data
# show the number of rows and columns of data
# show the last 4 rows
# show the categories present in type column
# show the data according to decreasing order of price 
# show the model,price and weight of all cars
# show the number of cars present in each origin
# show the average price of each type of cars
# show the top 3 models having highest weight
# show the top 3 type of cars having highest average price
# show the average enginesize 
# show the lowest weight
# show the cars having airbags for driver only
# show the models having price more than 20 of large or midsize type from usa

# %%
# show the top 3 rows of data
df.head(3)
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                 NaN  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
#
#    Turn.circle  Rear.seat.room Luggage.room  Weight   Origin           Make
# 0           37            26.5         11.0    2705  non-USA  Acura Integra
# 1           38            30.0         15.0    3560  non-USA   Acura Legend
# 2           37            28.0         14.0    3375  non-USA        Audi 90
#
# [3 rows x 28 columns]

# %%
# show the number of rows and columns of data
df.shape
# Out:
# (93, 28)

# %%
# show the last 4 rows
df.tail(4)
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 89           30                 NaN  ...          5    180        103     67
# 90           25                 NaN  ...          4    159         97     66
# 91           28         Driver only  ...          5    190        104     67
# 92           28  Driver & Passenger  ...          5    184        105     69
#
#     Turn.circle  Rear.seat.room Luggage.room  Weight   Origin  \
# 89           35            31.5         14.0    2985  non-USA
# 90           36            26.0         15.0    2810  non-USA
# ...

# %%
# show the categories present in type column
df['Type']
# Out:
# 0       Small
# 1     Midsize
# 2     Compact
# 3     Midsize
# 4     Midsize
#        ...
# 88        Van
# 89    Compact
# 90     Sporty
# 91    Compact
# 92    Midsize
# Name: Type, Length: 93, dtype: object

# %%
# show the data according to decreasing order of price 
df.sort_values(by='Price',ascending=False)
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 58  59  Mercedes-Benz      300E  Midsize       43.8   61.9       80.0
# 47  48       Infiniti       Q45  Midsize       45.4   47.9       50.4
# 10  11       Cadillac   Seville  Midsize       37.5   40.1       42.7
# 18  19      Chevrolet  Corvette   Sporty       34.6   38.0       41.5
# 3    4           Audi       100  Midsize       30.8   37.7       44.6
# ..  ..            ...       ...      ...        ...    ...        ...
# 38  39            Geo     Metro    Small        6.7    8.4       10.0
# 79  80         Subaru     Justy    Small        7.3    8.4        9.5
# 52  53          Mazda       323    Small        7.4    8.3        9.1
# 43  44        Hyundai     Excel    Small        6.8    8.0        9.2
# 30  31           Ford   Festiva    Small        6.9    7.4        7.9
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# ...

# %%
# show the model,price and weight of all cars
df[['Model','Price','Weight']]
# Out:
#       Model  Price  Weight
# 0   Integra   15.9    2705
# 1    Legend   33.9    3560
# 2        90   29.1    3375
# 3       100   37.7    3405
# 4      535i   30.0    3640
# ..      ...    ...     ...
# 88  Eurovan   19.7    3960
# 89   Passat   20.0    2985
# 90  Corrado   23.3    2810
# 91      240   22.7    2985
# 92      850   26.7    3245
#
# [93 rows x 3 columns]

# %%
# show the number of cars present in each origin
df['Origin'].value_counts()
# Out:
# Origin
# USA        48
# non-USA    45
# Name: count, dtype: int64

# %%
# show the average price of each type of cars
df.groupby(by='Type')['Price'].mean()
# Out:
# Type
# Compact    18.212500
# Large      24.300000
# Midsize    27.218182
# Small      10.166667
# Sporty     19.392857
# Van        19.100000
# Name: Price, dtype: float64

# %%
# show the top 3 models having highest weight
df.groupby(by='Weight')['Model'].head(3)
# Out:
# 0     Integra
# 1      Legend
# 2          90
# 3         100
# 4        535i
#        ...
# 88    Eurovan
# 89     Passat
# 90    Corrado
# 91        240
# 92        850
# Name: Model, Length: 93, dtype: object

# %%
# show the top 3 type of cars having highest average price
df.groupby(by='Type')['Price'].mean().sort_values(ascending=False).head(3)
# Out:
# Type
# Midsize    27.218182
# Large      24.300000
# Sporty     19.392857
# Name: Price, dtype: float64

# %%
# show the average enginesize 
df['EngineSize'].mean()
# Out:
# 2.6677419354838716

# %%
df.columns
# Out:
# Index(['id', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
# show the lowest weight
df['Weight'].min()
# Out:
# 1695

# %%
# show the cars having airbags for driver only
df['AirBags'][(df('AirBags')=='Driver only')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 2
#       1 # show the cars having airbags for driver only
# ----> 2 df['AirBags'][(df('AirBags')=='Driver only')]
#
# TypeError: 'DataFrame' object is not callable

# %%
df['AirBags']
# Out:
# 0                    NaN
# 1     Driver & Passenger
# 2            Driver only
# 3                    NaN
# 4            Driver only
#              ...
# 88                   NaN
# 89                   NaN
# 90                   NaN
# 91           Driver only
# 92    Driver & Passenger
# Name: AirBags, Length: 93, dtype: object

# %% [markdown]
# # visualization

# %% [markdown]
# # 1.bar Chart

# %%
df['Type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type'>

# %% [markdown]
# # 2.Pie chart

# %%
df['Type'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 3.line chart

# %%
df['Type'].value_counts().plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # 5.horizontal chart

# %%
df['Origin'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Origin'>

# %%
# show the number of cars from usa and non usa in bar chart
df['Origin'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Origin'>

# %%
# show the proportion of cars of usa and non usa
df['Origin'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # on numeric columns

# %% [markdown]
# ## 1.Boxplot >> outliers detection

# %%
import seaborn as sns

# %%
sns.boxplot(data=df,x='Price')
# Out:
# <Axes: xlabel='Price'>

# %%
# check outliers in weight columns
sns.boxplot(data=df,x='Weight')
# Out:
# <Axes: xlabel='Weight'>

# %%
# check outliers in horsepower
sns.boxplot(data=df,x='Horsepower')
# Out:
# <Axes: xlabel='Horsepower'>

# %% [markdown]
# ## 2. histogram >> distribution of column

# %%
sns.histplot(data=df,x='Price')
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(data=df,x='Weight',kde=True) >> kde means kernal density
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
sns.histplot(data=df,x='Length')# normal
# Out:
# <Axes: xlabel='Length', ylabel='Count'>

# %%
df
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
sns.histplot(data=df,x='Min.Price') # right
# Out:
# <Axes: xlabel='Min.Price', ylabel='Count'>

# %%
sns.histplot(data=df,x='Max.Price',kde=True) # right
# Out:
# <Axes: xlabel='Max.Price', ylabel='Count'>

# %%
sns.histplot(data=df,x='MPG.city',kde=True) # right
# Out:
# <Axes: xlabel='MPG.city', ylabel='Count'>

# %%
sns.histplot(data=df,x='Passengers',kde=True) # normal
# Out:
# <Axes: xlabel='Passengers', ylabel='Count'>

# %%
sns.histplot(data=df,x='Wheelbase',kde=True) # normal
# Out:
# <Axes: xlabel='Wheelbase', ylabel='Count'>

# %%
sns.histplot(data=df,x='Width',kde=True) # normal
# Out:
# <Axes: xlabel='Width', ylabel='Count'>

# %%
sns.histplot(data=df,x='Turn.circle',kde=True) # normal
# Out:
# <Axes: xlabel='Turn.circle', ylabel='Count'>

# %%
sns.histplot(data=df,x='Rear.seat.room',kde=True) # normal
# Out:
# <Axes: xlabel='Rear.seat.room', ylabel='Count'>

# %%
sns.histplot(data=df,x='Luggage.room',kde=True)# normal
# Out:
# <Axes: xlabel='Luggage.room', ylabel='Count'>

# %%
# show all numeric  columns in one code
from matplotlib.pyplot import show
for i in df.columns:
    if df[i].dtype!=object:
        sns.histplot(data=df,x=i,kde=True)
        show()

# %%
df['Min.Price'].mean()
# Out:
# 17.125806451612902

# %%
df['Min.Price'].median()
# Out:
# 14.7

# %%
# show the value counts of all catergorical  columns in bar chart
from matplotlib.pyplot import show
for i in df.columns:
    if df[i].dtypes==object:
        df[i].value_counts().plot(kind='bar')
        show()
